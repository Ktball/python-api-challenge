# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations    
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
  
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 591

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL

url = "https://api.openweathermap.org/data/2.5/weather?lat=%s&lon=%s&appid=%s"


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    #city_url = # YOUR CODE HERE  
    city_url = "https://api.openweathermap.org/geo/1.0/direct?q=%s&limit=5&appid=%s" % (city, weather_api_key)
    #print(city_url)
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        response = requests.get(city_url)
        lat = response.json()[0]['lat']
        lon = response.json()[0]['lon']
        # Parse the JSON and retrieve data
        #city_weather = # YOUR CODE HERE
        city_weather = requests.get(url % (lat, lon, weather_api_key), params={'units': 'metric'}).json()
        print(url % (lat, lon, weather_api_key))
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date
                         }
                        )

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | siquijor
# https://api.openweathermap.org/data/2.5/weather?lat=9.2155864&lon=123.5138212&appid=311b3d7d630646e44d070fd233e99a8c
# Processing Record 2 of Set 1 | port-aux-francais
# https://api.openweathermap.org/data/2.5/weather?lat=-49.3497607&lon=70.2199565&appid=311b3d7d630646e44d070fd233e99a8c
# Processing Record 3 of Set 1 | kon tum
# https://api.openweathermap.org/data/2.5/weather?lat=14.3615256&lon=108.0039102&appid=311b3d7d630646e44d070fd233e99a8c
# Processing Record 4 of Set 1 | celestun
# https://api.openweathermap.org/data/2.5/weather?lat=20.8604208&lon=-90.3994361&appid=311b3d7d630646e44d070fd233e99a8c
# Processing Record 5 of Set 1 | undurkhaan
# https://api.openweathermap.org/data/2.5/weather?lat=47.3256114&lon=110.6649133&appid=311b3d7d630646e44d070fd233e99a8c
# Processing Record 6 of Set 1 | saipan
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          545
# Lat           545
# Lng           545
# Max Temp      545
# Humidity      545
# Cloudiness    545
# Wind Speed    545
# Country       545
# Date          545
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           siquijor   9.2156  123.5138     26.33        77           0
# 1  port-aux-francais -49.3498   70.2200      8.20        91         100
# 2            kon tum  14.3615  108.0039     17.27        93           4
# 3           celestun  20.8604  -90.3994     22.03        66          80
# 4         undurkhaan  47.3256  110.6649    -19.23        87          96
#
#    Wind Speed Country        Date
# 0        8.26      PH  1707831321
# 1       10.99      TF  1707831322
# 2        1.72      VN  1707831322
# 3        5.07      MX  1707831323
# 4        1.96      MN  1707831324

# %%
# Export the City_Data into a csv
city_data_df.to_csv("C:/Users/samka/upenn/MY_HOMEWORK/06-API-Challenge/python-api-challenge/output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("C:/Users/samka/upenn/MY_HOMEWORK/06-API-Challenge/python-api-challenge/output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 siquijor   9.2156  123.5138     26.33        77           0
# 1        port-aux-francais -49.3498   70.2200      8.20        91         100
# 2                  kon tum  14.3615  108.0039     17.27        93           4
# 3                 celestun  20.8604  -90.3994     22.03        66          80
# 4               undurkhaan  47.3256  110.6649    -19.23        87          96
#
#          Wind Speed Country        Date
# City_ID
# 0              8.26      PH  1707831321
# 1             10.99      TF  1707831322
# 2              1.72      VN  1707831322
# 3              5.07      MX  1707831323
# 4              1.96      MN  1707831324

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lat_temp_df = pd.DataFrame(city_data)
latitude = lat_temp_df["Lat"]
temperature = lat_temp_df["Max Temp"]
#converted_temp = temperature - 273.15
plt.scatter(latitude, temperature)

# Incorporate the other graph properties
plt.title('Latitude vs. Temperature')
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.grid(True)
# Save the figure
#city_data_df = pd.read_csv("C:/Users/samka/upenn/MY_HOMEWORK/06-API-Challenge/python-api-challenge/output_data/cities.csv", index_col="City_ID")
plt.savefig("C:/Users/samka/upenn/MY_HOMEWORK/06-API-Challenge/python-api-challenge/output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
lat_humidity_df = pd.DataFrame(city_data)
latitude = lat_temp_df["Lat"]
humidity = lat_temp_df["Humidity"]
plt.scatter(latitude, humidity)
# Incorporate the other graph properties
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)
# Save the figure
plt.savefig("C:/Users/samka/upenn/MY_HOMEWORK/06-API-Challenge/python-api-challenge/output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
lat_cloudiness_df = pd.DataFrame(city_data)
latitude = lat_temp_df["Lat"]
cloudiness = lat_temp_df["Cloudiness"]
plt.scatter(latitude, cloudiness)
# Incorporate the other graph properties
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)
# Save the figure
plt.savefig("C:/Users/samka/upenn/MY_HOMEWORK/06-API-Challenge/python-api-challenge/output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
lat_wind_speed_df = pd.DataFrame(city_data)
latitude = lat_temp_df["Lat"]
wind_speed = lat_temp_df["Wind Speed"]
plt.scatter(latitude, wind_speed)

# Incorporate the other graph properties
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid(True)
# Save the figure
plt.savefig("C:/Users/samka/upenn/MY_HOMEWORK/06-API-Challenge/python-api-challenge/output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq, (min(x_values), max(y_values)), color="r", fontsize=15)
    print(f"The r-squared is: {rvalue**2}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = pd.DataFrame(city_data_df.loc[(city_data_df['Lat']>=0),:])
# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          siquijor   9.2156  123.5138     26.33        77           0
# 2           kon tum  14.3615  108.0039     17.27        93           4
# 3          celestun  20.8604  -90.3994     22.03        66          80
# 4        undurkhaan  47.3256  110.6649    -19.23        87          96
# 5            saipan  15.1910  145.7467     22.11        88          75
#
#          Wind Speed Country        Date
# City_ID
# 0              8.26      PH  1707831321
# 2              1.72      VN  1707831322
# 3              5.07      MX  1707831323
# 4              1.96      MN  1707831324
# 5              9.77      MP  1707831325

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = pd.DataFrame(city_data_df.loc[(city_data_df['Lat']<0),:])

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        port-aux-francais -49.3498   70.2200      8.20        91         100
# 6                  huarmey -10.0687  -78.1522     25.48        77          72
# 7                 waitangi -35.2705  174.0805     16.98        88           9
# 8                adamstown -25.0667 -130.1002     24.67        89         100
# 14               jamestown -15.9277   -5.7161     24.36        77          49
#
#          Wind Speed Country        Date
# City_ID
# 1             10.99      TF  1707831322
# 6              3.01      PE  1707831326
# 7              0.71      NZ  1707831327
# 8              7.13      PN  1707831327
# 14             6.50      SH  1707831332

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,-40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7171271359172866

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,35),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.373910157107404

# %% [markdown]
# **Discussion about the linear relationship:** The r_value is positive for the Northern and Southern Hemispheres indicating temperature increase closer to the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50, 0),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.20722939435250456

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.059055693365815856

# %% [markdown]
# **Discussion about the linear relationship:** The r_value for Humidity versus Latitude is positive indicating increase in humidity closer to the equator.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.text(10, 70, line_eq, ha='center', va='center', transform=plt.gca().transAxes)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.04864894941396635

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Cloudiness']
y_values = southern_hemi_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,-50),fontsize=15,color="red")
plt.xlabel('Cloudiness')
plt.ylabel('Latitude')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.06700411810103139

# %% [markdown]
# **Discussion about the linear relationship:** The r_value is positive for Cloudiness versus Latitude. There is more cloudiness the further away from the equator.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,12),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.015479204993950346

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.06439884997168518

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
The r_value is positive indicating the wind speed increases moving further away from the equator.
